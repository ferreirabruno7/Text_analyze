# %%
from twitter import *
import json

# %%
CONSUMER_KEY = 'EnELVcesJEGCbCyG3upiNFuMT'
CONSUMER_SECRET = 'nCX6yWVVZIk24NXDSdznpmyGTAFDEirsWHJ9xE0v5UFHPkVBkf'
OAUTH_TOKEN = '55943119-cXi7Xl0DDmoxwVcMyrf80v7woheh9YxnNwmAh8YSM'
OAUTH_TOKEN_SECRET = 'fOUYMQcyNAO3X2siI4aWCwE8Q9p2ZLdxDh04xmaNgsC8l'

t = Twitter(
    auth=OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET))
print(t)

# %%
brasilia = 455819
brasil = 23424768

# %%
brasilia_trends = t.trends.place(_id=brasilia)

# %%
print(json.dumps(brasilia_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "David Silva",
#     "url": "http://twitter.com/search?q=%22David+Silva%22",
#     "promoted_content": null,
#     "query": "%22David+Silva%22",
#     "tweet_volume": 10893
#    },
#    {
#     "name": "#DomingoDetremuraSDV",
#     "url": "http://twitter.com/search?q=%23DomingoDetremuraSDV",
#     "promoted_content": null,
#     "query": "%23DomingoDetremuraSDV",
#     "tweet_volume": 16022
#    },
#    {
#     "name": "Huddersfield",
#     "url": "http://twitter.com/search?q=Huddersfield",
#     "promoted_content": null,
#     "query": "Huddersfield",
#     "tweet_volume": 25784
#    },
#    {
#     "name": "Vamos Flamengo",
#     "url": "http://twitter.com/search?q=%22Vamos+Flamengo%22",
#     "promoted_content": null,
#     "query": "%22Vamos+Flamengo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mendy",
#     "url": "http://twitter.com/search?q=Mendy",
#     "promoted_content": null,
#     "query": "Mendy",
# ...

# %%
brasilia = 455819
brasil = 23424768

# %%
brasil_trends = t.trends.place(_id=brasil)
brasilia_trends = t.trends.place(_id=brasilia)

# %%
brasil_trends_set = set([trend['name'] for trend in brasil_trends[0]['trends']])
brasilia_trends_set = set([trend['name'] for trend in brasilia_trends[0]['trends']])


common_trends = brasil_trends_set.intersection(brasilia_trends_set)

print(common_trends)
# Out:
# {'Internacional x Paraná', '#TVDnoSBT', 'Mendy', '#AltasHoras', 'Arsenal', '#7YearsOfLittleMix', '#DiaMundialDaFotografia', 'Bruno Grassi', '#DebateRedeTV', '#SoTocaTop', 'David Silva', 'AVRIL LAVIGNE IS COMING', 'Roraima', 'Sardenberg', 'Barbados', '#LNFnoSporTV', 'Huddersfield', '#SBT37Anos', '#DomingoDetremuraSDV', '#GloboRural', 'Kofi Annan', '#BakeOffBrasil', 'Janio de Freitas', '#QueriadizerQ', 'QUE NOITE', 'Emerson Santos', '#VoleiNoSporTV', '#CriançaEsperança', '#50MilNoArruda', 'Fake ONU', '#AssedioÉHabitoNoPensi', '#CBLoL', 'VAMOS FLAMENGO', 'Lara Jean', '#CiteUmaTretaESaia', 'VAMO INTER', '#TheFameTurns10', 'HOJE TEM SÃO PAULO', '#fcseguindofcs', '#40AnosRestauracao', 'Shania Twain', '#DiaDeFlu', '#LOONAbirth', '#MCIHUD', 'Loss', 'Morata', 'Marina', 'Garota Vip', 'Tirei 100%'}

# %%
from urllib.parse import unquote
q = '#DebateBandDF'
count = 100

# %%
statusses = t.search.tweets(q="#DebateBandDF")
status = statusses['statuses']

# %%
print(json.dumps(status[0], indent=1))
# Out:
# {
#  "created_at": "Sat Aug 18 17:01:25 +0000 2018",
#  "id": 1030862239736229888,
#  "id_str": "1030862239736229888",
#  "text": "RT @eldogomes: Promessa de Rollemberg era o Metr\u00f4 at\u00e9 a Expans\u00e3o de Samambaia e at\u00e9 a asa norte. \n\"Candidato @RollembergPSB , onde est\u00e1 a e\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "eldogomes",
#     "name": "ELDO GOMES",
#     "id": 24759997,
#     "id_str": "24759997",
#     "indices": [
#      3,
#      13
#     ]
#    },
#    {
#     "screen_name": "RollembergPSB",
#     "name": "Rodrigo Rollemberg",
#     "id": 53050115,
#     "id_str": "53050115",
#     "indices": [
#      109,
#      123
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "pt",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
# ...

# %%
status_text =
# Out:
# Tamano do Status 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-7b9fcc9f6ae9> in <module>()
#       6         break
#       7
# ----> 8     kwargs = dict([kv.split('=') for kv in unquote(next_results[1:].split("&"))])
#       9     statusses = t.search.tweets(**kwargs)
#      10     status +=  statusses['statuses']
#
# C:\ProgramData\Anaconda3\lib\urllib\parse.py in unquote(string, encoding, errors)
#     607     """
#     608     if '%' not in string:
# --> 609         string.split
#     610         return string
#     611     if encoding is None:
#
# AttributeError: 'list' object has no attribute 'split'
