# %%
import nltk
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
import re
import operator
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import words
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
# If you would like to work with the raw text you can use 'moby_raw'
with open('C:/Users/NB/Desktop/extração/extratacao_semanal/post_rodrigo.csv',  encoding='utf-8',) as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)

# %%
from nltk.corpus import stopwords

# %%
retira = set(stopwords.words('portuguese'))

# %%
filtra = lambda w: len(w) <3 or w in retira

# %%
procurar = BigramCollocationFinder.from_words(moby_tokens)
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('#', 'EquipePSB_DF'),
#  ('!', '!'),
#  ('EquipePSB_DF', "''"),
#  ("''", "''"),
#  ('Rodrigo', 'Rollemberg'),
#  ('Um', 'abraço'),
#  ('?', '?'),
#  ('pelo', 'apoio'),
#  ("''", '``'),
#  ("''", 'Olá'),
#  ('Distrito', 'Federal'),
#  ('do', 'DF'),
#  ('à', 'disposição'),
#  ('!', '#'),
#  ('http', ':'),
#  ('Obrigado', 'pelo'),
#  ('o', 'senhor'),
#  ('4', 'anos'),
#  (':', '//giphy.com/gifs/5YlaI0TvflNPoliowc'),
#  ('Estamos', 'à'),
#  ('Muito', 'obrigado'),
#  ('.', 'Um'),
#  ('rede', 'pública'),
#  ('com', 'a'),
#  ('Estamos', 'juntos'),
#  ('.', "''"),
#  ('todos', 'os'),
#  ('casa', 'arrumada'),
#  ('a', 'casa'),
#  ('em', 'frente')]

# %%
procurar.apply_word_filter(filtra)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('Rodrigo', 'Rollemberg'),
#  ('Distrito', 'Federal'),
#  ('Muito', 'obrigado'),
#  ('rede', 'pública'),
#  ('Estamos', 'juntos'),
#  ('casa', 'arrumada'),
#  ('Além', 'disso'),
#  ('Instituto', 'Hospital'),
#  ('107', 'leitos'),
#  ('fez', 'nada'),
#  ('seguimos', 'empenhados'),
#  ('desenvolvimento', 'social'),
#  ('Bom', 'dia'),
#  ('forte', 'abraço'),
#  ('reabrir', '107'),
#  ('conseguimos', 'reabrir'),
#  ('aguardam', 'nomeação'),
#  ('quatro', 'anos'),
#  ('rumo', 'certo'),
#  ('Boa', 'tarde'),
#  ('dívida', 'bilionária'),
#  ('últimos', 'anos'),
#  ('grandes', 'conquistas'),
#  ('restrições', 'financeiras'),
#  ('cursos', 'profissionalizantes'),
#  ('Unidades', 'Básicas'),
#  ('novas', 'vagas'),
#  ('Centro', 'Interescolares'),
#  ('Enfrentamos', 'muitas'),
#  ('Câmara', 'Legislativa')]

# %%
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures

# %%
procurar2 = TrigramCollocationFinder.from_words(moby_tokens)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('#', 'CasaArrumada', '#'),
#  ('#', 'Rollemberg40', '#'),
#  ('#', 'HoradaVirada', '#'),
#  ('#', 'DebateBandDF', '#'),
#  ('#', 'HoraDaVirada', '#'),
#  ('#', 'RollembergNaBand', '#'),
#  ('#', 'RollembergnaBand', '#'),
#  ('#', 'FimdaCriseHídrica', '#'),
#  ('#', 'OrlaLivre', '#'),
#  ('#', 'PSB', '#'),
#  ('#', 'RodrigoRollemberg', '#'),
#  ('do', 'Distrito', 'Federal'),
#  ('CasaArrumada', '#', 'HoradaVirada'),
#  ('HoradaVirada', '#', 'CasaArrumada'),
#  ('CasaArrumada', '#', 'DebateBandDF'),
#  ('Distrito', 'Federal', 'desde'),
#  ('Distrito', 'Federal', '.'),
#  ('Distrito', 'Federal', 'estão'),
#  ('Distrito', 'Federal', 'vem'),
#  ('Distrito', 'Federal', '('),
#  ('ao', 'Distrito', 'Federal'),
#  ('no', 'Distrito', 'Federal'),
#  ('Distrito', 'Federal', 'em'),
#  ('Distrito', 'Federal', 'com'),
#  ('Distrito', 'Federal', 'o'),
#  ('DebateBandDF', '#', 'Rollemberg40'),
#  ('CasaArrumada', '#', 'HoraDaVirada'),
#  ('!', '#', 'CasaArrumada'),
#  ('RollembergnaBand', '#', 'CasaArrumada'),
#  ('Rollemberg40', '#', 'CasaArrumada')]

# %%
texto = [w.lower() for w in webtext.words('C:/Users/NB/Desktop/extração/extratacao_semanal/post_rodrigo.csv')]

# %%
texto
# Out:
# ['ďťżpost_message',
#  'vamos',
#  'juntos',
#  '!',
#  'iniciaremos',
#  'nessa',
#  'quinta',
#  '-',
#  'feira',
#  '(',
#  '16',
#  ')',
#  'a',
#  'campanha',
#  'de',
#  'reeleiă',
#  '§',
#  'ăło',
#  'ao',
#  'governo',
#  'do',
#  'distrito',
#  'federal',
#  'com',
#  'uma',
#  'caminhada',
#  'pelas',
#  'ruas',
#  'do',
#  'sol',
#  'nascente',
#  'em',
#  'ceilă',
#  '˘',
#  'ndia',
#  '.',
#  'estarei',
#  'muito',
#  'bem',
#  'acompanhado',
#  'pelos',
#  'meus',
#  'parceiros',
#  'leila',
#  'do',
#  'vă',
#  '´',
#  'lei',
#  'e',
#  'chico',
#  'leite',
#  '.',
#  'a',
#  'concentraă',
#  '§',
#  'ăło',
#  'serăą',
#  'a',
#  'partir',
#  'das',
#  '8h',
#  'no',
#  'trecho',
#  'i',
#  'em',
#  'frente',
#  'ă',
#  'feira',
#  'do',
#  'produtor',
#  '.',
#  'participe',
#  'da',
#  'caminhada',
#  '40',
#  '!',
#  '#',
#  'rollemberg40',
#  '#',
#  'casaarrumada',
#  '#',
#  'horadavirada',
#  '#',
#  'caminhada40',
#  'vamos',
#  'juntos',
#  'que',
#  'o',
#  'caminho',
#  'ăš',
#  'de',
#  'vităłria',
#  '!',
#  'a',
#  'caminhada',
#  '40',
#  'vai',
#  'passar',
#  'neste',
#  'săąbado',
#  '(',
#  '18',
#  ')',
#  'por',
#  'ceilă',
#  '˘',
#  'ndia',
#  '.',
#  'uma',
#  'ăłtima',
#  'oportunidade',
#  'para',
#  'conferir',
#  'tantos',
#  'avană',
#  '§',
#  'os',
#  'garantidos',
#  'pelo',
#  'nosso',
#  'governo',
#  'nos',
#  'ăşltimos',
#  'trăşs',
#  'anos',
#  'em',
#  'benefă',
#  '\xad',
#  'cio',
#  'da',
#  'populaă',
#  '§',
#  'ăło',
#  'da',
#  'cidade',
#  '.',
#  'estarei',
#  'muito',
#  'bem',
#  'acompanhado',
#  'pelos',
#  'meus',
#  'parceiros',
#  'leila',
#  'do',
#  'vă',
#  '´',
#  'lei',
#  'e',
#  'chico',
#  'leite',
#  'alăšm',
#  'de',
#  'diversos',
#  'amigos',
#  'candidatos',
#  'e',
#  'apoiadores',
#  '.',
#  'a',
#  'concentraă',
#  '§',
#  'ăło',
#  'serăą',
#  'ă',
#  's',
#  '6h',
#  'na',
#  'feira',
#  'do',
#  'produtor',
#  'de',
#  'ceilă',
#  '˘',
#  'ndia',
#  'na',
#  'qnp',
#  '01',
#  'setor',
#  'p',
#  'norte',
#  '.',
#  'vem',
#  'com',
#  'a',
#  'gente',
#  '!',
#  '#',
#  'rollemberg40',
#  '#',
#  'casaarrumada',
#  '#',
#  'horadavirada',
#  '#',
#  'caminhada40',
#  'sei',
#  'que',
#  'hoje',
#  'o',
#  'que',
#  'sou',
#  'ăš',
#  'por',
#  'conta',
#  'dos',
#  'ensinamentos',
#  'do',
#  'meu',
#  'pai',
#  'armando',
#  'rollemberg',
#  'e',
#  'da',
#  'minha',
#  'măłe',
#  'teresa',
#  '.',
#  'com',
#  'eles',
#  'e',
#  'ao',
#  'lado',
#  'dos',
#  'meus',
#  'irmăłos',
#  'aprendi',
#  'a',
#  'dividir',
#  'a',
#  'ser',
#  'solidăąrio',
#  '!',
#  'nesse',
#  'vă',
#  '\xad',
#  'deo',
#  'conto',
#  'um',
#  'pouco',
#  'mais',
#  'dessa',
#  'histăłria',
#  '.',
#  'desejo',
#  'a',
#  'todos',
#  'um',
#  'feliz',
#  'dia',
#  'dos',
#  'pais',
#  '!',
#  'que',
#  'deus',
#  'abenă',
#  '§',
#  'oe',
#  'a',
#  'todos',
#  '.',
#  'rodrigo',
#  'rollemberg',
#  'updated',
#  'their',
#  'profile',
#  'picture',
#  '.',
#  'rodrigo',
#  'rollemberg',
#  'updated',
#  'their',
#  'cover',
#  'photo',
#  '.',
#  'prestigiei',
#  'nesta',
#  'quarta',
#  '-',
#  'feira',
#  '(',
#  '15',
#  ')',
#  'a',
#  'entrega',
#  'do',
#  'espadim',
#  'a',
#  '115',
#  'cadetes',
#  'do',
#  'curso',
#  'de',
#  'formaă',
#  '§',
#  'ăło',
#  'de',
#  'oficiais',
#  'da',
#  'pmdf',
#  '.',
#  'săło',
#  'pessoas',
#  'muito',
#  'qualificadas',
#  '.',
#  'tenho',
#  'convică',
#  '§',
#  'ăło',
#  'que',
#  'darăło',
#  'uma',
#  'contribuiă',
#  '§',
#  'ăło',
#  'enorme',
#  'para',
#  'a',
#  'nossa',
#  'populaă',
#  '§',
#  'ăło',
#  '.',
#  'ă',
#  '\x89',
#  'importante',
#  'registrar',
#  'que',
#  'a',
#  'pmdf',
#  'ăš',
#  'a',
#  'ăşnica',
#  'polă',
#  '\xad',
#  'cia',
#  'do',
#  'brasil',
#  'que',
#  'tem',
#  'a',
#  'sua',
#  'qualificaă',
#  '§',
#  'ăło',
#  'atestada',
#  'pelo',
#  'mec',
#  'como',
#  'curso',
#  'superior',
#  'de',
#  'excelăşncia',
#  '.',
#  'đ',
#  '\x9f\x91\x8f',
#  'đ',
#  '\x9f\x91\x8d',
#  'o',
#  'programa',
#  '#',
#  'boravencer',
#  'jăą',
#  'capacitou',
#  'mais',
#  'de',
#  '50',
#  'mil',
#  'jovens',
#  'tanto',
#  'para',
#  'o',
#  'enem',
#  'quanto',
#  'para',
#  'concursos',
#  '.',
#  'tambăšm',
#  'ajudou',
#  'cerca',
#  'de',
#  '2',
#  '.',
#  '500',
#  'alunos',
#  'a',
#  'entrarem',
#  'em',
#  'universidades',
#  'păşblicas',
#  'do',
#  'distrito',
#  'federal',
#  '(',
#  'unb',
#  'escs',
#  'ifb',
#  ').',
#  'esse',
#  'ăš',
#  'o',
#  'maior',
#  'ă',
#  '\xad',
#  'ndice',
#  'da',
#  'histăłria',
#  'de',
#  'alunos',
#  'que',
#  'ingressaram',
#  'em',
#  'universidades',
#  'federais',
#  '.',
#  'considero',
#  'essa',
#  'uma',
#  'das',
#  'coisas',
#  'mais',
#  'bonitas',
#  'que',
#  'estamos',
#  'fazendo',
#  'em',
#  'brasă',
#  '\xad',
#  'lia',
#  '.',
#  'reforă',
#  '§',
#  'a',
#  'ainda',
#  'mais',
#  'a',
#  'importă',
#  '˘',
#  'ncia',
#  'de',
#  'projetos',
#  'para',
#  'democratizar',
#  'o',
#  'acesso',
#  'em',
#  'nossas',
#  'universidades',
#  '.',
#  'educaă',
#  '§',
#  'ăło',
#  'sempre',
#  'ăš',
#  'uma',
#  'prioridade',
#  '!',
#  'o',
#  'peră',
#  '\xad',
#  'odo',
#  'eleitoral',
#  'comeă',
#  '§',
#  'ou',
#  'oficialmente',
#  'e',
#  'hoje',
#  'serăą',
#  'o',
#  'primeiro',
#  'debate',
#  'de',
#  'candidatos',
#  'ao',
#  'governo',
#  'do',
#  'distrito',
#  'federal',
#  '.',
#  'acompanhe',
#  'a',
#  'partir',
#  'das',
#  '22h',
#  'na',
#  'tv',
#  'band',
#  '.',
#  'serăą',
#  'uma',
#  'excelente',
#  'oportunidade',
#  'para',
#  'conhecer',
#  'nossas',
#  'propostas',
#  'para',
#  'continuar',
#  'melhorando',
#  'brasă',
#  '\xad',
#  'lia',
#  '.',
#  'vamos',
#  'em',
#  'frente',
#  '!',
#  '.',
#  '#',
#  'rollemberg40',
#  '#',
#  'casaarrumada',
#  '#',
#  'horadavirada',
#  'o',
#  'jogo',
#  'sujo',
#  'do',
#  'submundo',
#  'da',
#  'polă',
#  '\xad',
#  'tica',
#  'comeă',
#  '§',
#  'ou',
#  '.',
#  'alguns',
#  'blogs',
#  'financiados',
#  'pela',
#  'mesma',
#  'turma',
#  'que',
#  'montou',
#  'o',
#  'maior',
#  'esquema',
#  'de',
#  'corrupă',
#  '§',
#  'ăło',
#  'do',
#  'distrito',
#  'federal',
#  'estăło',
#  'divulgando',
#  'diversas',
#  'inverdades',
#  '.',
#  'fique',
#  'atento',
#  '!',
#  'năło',
#  'se',
#  'deixe',
#  'levar',
#  'por',
#  'fake',
#  'news',
#  '.',
#  'da',
#  'nossa',
#  'parte',
#  'vocăş',
#  'pode',
#  'ter',
#  'a',
#  'certeza',
#  'de',
#  'que',
#  'vamos',
#  'fazer',
#  'a',
#  'nossa',
#  'campanha',
#  'de',
#  'forma',
#  'limpa',
#  '.',
#  'em',
#  'respeito',
#  'a',
#  'vocăş',
#  '.',
#  'em',
#  'respeito',
#  'ao',
#  'distrito',
#  'federal',
#  '.',
#  'dăş',
#  'o',
#  'play',
#  '.',
#  'nosso',
#  'governo',
#  'garantiu',
#  'a',
#  'orla',
#  'livre',
#  'para',
#  'toda',
#  'a',
#  'populaă',
#  '§',
#  'ăło',
#  'do',
#  'df',
#  'pois',
#  'năło',
#  'dividimos',
#  'o',
#  'cidadăło',
#  'em',
#  'duas',
#  'categorias',
#  '.',
#  'queremos',
#  'que',
#  'qualquer',
#  'pessoa',
#  'possa',
#  'usufruir',
#  'desse',
#  'espaă',
#  '§',
#  'o',
#  'que',
#  'ăš',
#  'păşblico',
#  '.',
#  'o',
#  'lago',
#  'ăš',
#  'a',
#  'nossa',
#  'praia',
#  '.',
#  'e',
#  'a',
#  'praia',
#  'ăš',
#  'de',
#  'todos',
#  '!',
#  '#',
#  'orlalivre',
#  '#',
#  'horadavirada',
#  '#',
#  'casaarrumada',
#  '#',
#  'debatebanddf',
#  '#',
#  'rollemberg40',
#  'nosso',
#  'governo',
#  'estăą',
#  'deixando',
#  'legados',
#  'para',
#  'a',
#  'cidade',
#  'e',
#  'para',
#  'todas',
#  'as',
#  'geraă',
#  '§',
#  'ăľes',
#  '.',
#  'a',
#  'exemplo',
#  'da',
#  'maior',
#  'obra',
#  'de',
#  'captaă',
#  '§',
#  'ăło',
#  'de',
#  'ăągua',
#  'do',
#  'brasil',
#  'a',
#  'de',
#  'corumbăą',
#  'iv',
#  'que',
#  'ficarăą',
#  'pronta',
#  'atăš',
#  'o',
#  'fim',
#  'deste',
#  'ano',
#  'e',
#  'vai',
#  'garantir',
#  'distribuiă',
#  '§',
#  'ăło',
#  'de',
#  'ăągua',
#  'para',
#  'todos',
#  '.',
#  '#',
#  'fimdacrisehă',
#  '\xad',
#  'drica',
#  '#',
#  'horadavirada',
#  '#',
#  'casaarrumada',
#  '#',
#  'debatebanddf',
#  '#',
#  'rollemberg40',
#  'no',
#  'primeiro',
#  'dia',
#  'de',
#  'campanha',
#  'jăą',
#  'temos',
#  'boas',
#  'notă',
#  '\xad',
#  'cias',
#  '.',
#  'em',
#  'pesquisa',
#  'espontă',
#  '˘',
#  'nea',
#  'divulgada',
#  'pelo',
#  'jornal',
#  'correio',
#  'braziliense',
#  'e',
#  'feita',
#  'pelo',
#  'instituto',
#  'opiniăło',
#  'polă',
#  '\xad',
#  'tica',
#  'estamos',
#  'em',
#  'primeiro',
#  'lugar',
#  'com',
#  '6',
#  '%',
#  'das',
#  'intenă',
#  '§',
#  'ăľes',
#  'de',
#  'votos',
#  '.',
#  'temos',
#  'mais',
#  'que',
#  'o',
#  'dobro',
#  'do',
#  'segundo',
#  'colocado',
#  'que',
#  'ficou',
#  'com',
#  '2',
#  '9',
#  '%.',
#  'o',
#  'terceiro',
#  'estăą',
#  '2',
#  '8',
#  '%;',
#  'o',
#  'quarto',
#  'com',
#  '2',
#  '5',
#  '%',
#  'e',
#  'os',
#  'demais',
#  'candidatos',
#  'com',
#  '6',
#  '2',
#  '!%.',
#  'ainda',
#  'năło',
#  'sabem',
#  'avaliar',
#  '45',
#  '9',
#  '%',
#  'e',
#  'os',
#  'votos',
#  'brancos',
#  '/',
#  'nulos',
#  '/',
#  'nenhum',
#  'representam',
#  '32',
#  '1',
#  '%.',
#  'vamos',
#  'em',
#  'frente',
#  '!',
#  'no',
#  'meu',
#  'governo',
#  'as',
#  'mulheres',
#  'tiveram',
#  'papeis',
#  'importantes',
#  '.',
#  'tivemos',
#  'por',
#  'exemplo',
#  'a',
#  'ex',
#  '-',
#  'secretăąria',
#  'de',
#  'planejamento',
#  'leany',
#  'lemos',
#  ';',
#  'a',
#  'ex',
#  '-',
#  'secretăąria',
#  'de',
#  'esporte',
#  'leila',
#  'do',
#  'vă',
#  '´',
#  'lei',
#  'e',
#  'a',
#  'presidente',
#  'da',
#  'agăşncia',
#  'de',
#  'fiscalizaă',
#  '§',
#  'ăło',
#  '(',
#  'agefis',
#  ')',
#  'bruna',
#  'pinheiro',
#  '.',
#  'somente',
#  'no',
#  'centro',
#  'da',
#  'governană',
#  '§',
#  'a',
#  'temos',
#  'duas',
#  'mulheres',
#  '.',
#  'na',
#  'prăłxima',
#  'gestăło',
#  'metade',
#  'dos',
#  'cargos',
#  'de',
#  'direă',
#  '§',
#  'ăło',
#  'serăło',
#  'ocupados',
#  'por',
#  'elas',
#  '.',
#  '#',
#  'rollembergnaband',
#  '#',
#  'horadavirada',
#  '#',
#  'casaarrumada',
#  '#',
#  'debatebanddf',
#  '#',
#  'rollemberg40',
#  'no',
#  'ină',
#  '\xad',
#  'cio',
#  'do',
#  'dia',
#  'visitei',
#  'o',
#  'sol',
#  'nascente',
#  'em',
#  'ceilă',
#  '˘',
#  'ndia',
#  'com',
#  'amigos',
#  'candidatos',
#  'e',
#  'apoiadores',
#  'da',
#  'nossa',
#  'candidatura',
#  'ă',
#  'reeleiă',
#  '§',
#  'ăło',
#  'ao',
#  'governo',
#  'do',
#  'df',
#  '.',
#  'escolhi',
#  'comeă',
#  '§',
#  'ar',
#  'a',
#  'campanha',
#  'por',
#  'esta',
#  'regiăło',
#  'porque',
#  'tenho',
#  'uma',
#  'ligaă',
#  '§',
#  'ăło',
#  'muito',
#  'forte',
#  'com',
#  'os',
#  'moradores',
#  '.',
#  'foi',
#  'no',
#  'sol',
#  'nascente',
#  'que',
#  'hăą',
#  '4',
#  'anos',
#  'iniciamos',
#  'nossa',
#  'caminhada',
#  'rumo',
#  'ao',
#  'governo',
#  'do',
#  'distrito',
#  'federal',
#  '.',
#  'nada',
#  'mais',
#  'coerente',
#  'do',
#  'que',
#  'iniciar',
#  'um',
#  'novo',
#  'ciclo',
#  'por',
#  'ali',
#  '.',
#  'durante',
#  'o',
#  'governo',
#  'conseguimos',
#  'realizar',
#  'o',
#  'sonho',
#  'de',
#  'muitos',
#  'moradores',
#  '.',
#  'e',
#  'hoje',
#  ...]

# %%
procurar = BigramCollocationFinder.from_words(texto)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('§', 'ăło'),
#  ('distrito', 'federal'),
#  ('#', 'casaarrumada'),
#  ('#', 'horadavirada'),
#  ('casaarrumada', '#'),
#  ('#', 'rollemberg40'),
#  ('ceilă', '˘'),
#  ('˘', 'ndia'),
#  ('populaă', '§'),
#  ('´', 'lei'),
#  ('polă', '\xad'),
#  ('vă', '´'),
#  ('do', 'distrito'),
#  ('brasă', '\xad'),
#  ('\xad', 'lia'),
#  ('chico', 'leite'),
#  ('horadavirada', '#'),
#  ('\xad', 'tica'),
#  ('sol', 'nascente'),
#  ('ă', '\x89'),
#  ('nosso', 'governo'),
#  ('em', 'frente'),
#  ('vamos', 'juntos'),
#  ('leila', 'do'),
#  ('#', 'debatebanddf'),
#  ('debatebanddf', '#'),
#  ('ao', 'governo'),
#  ('espaă', '§'),
#  ('§', 'ăľes'),
#  ('neste', 'săąbado')]

# %%
from nltk.corpus import stopwords

# %%
retira = set(stopwords.words('portuguese'))

# %%
retira
# Out:
# {'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'não',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'à',
#  'às',
#  'éramos'}

# %%
filtra = lambda w: len(w) <4 or w in retira

# %%
procurar.apply_word_filter(filtra)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('distrito', 'federal'),
#  ('chico', 'leite'),
#  ('vamos', 'juntos'),
#  ('neste', 'săąbado'),
#  ('correio', 'braziliense'),
#  ('futuros', 'senadores'),
#  ('instituto', 'opiniăło'),
#  ('jornal', 'correio'),
#  ('nenhum', 'representam'),
#  ('sabem', 'avaliar'),
#  ('updated', 'their'),
#  ('continuar', 'trabalhando'),
#  ('rodrigo', 'rollemberg'),
#  ('rollemberg', 'updated'),
#  ('votos', 'brancos'),
#  ('conseguimos', 'colocar'),
#  ('maior', 'obra'),
#  ('parceiros', 'leila'),
#  ('răądio', 'band'),
#  ('senadores', 'leila'),
#  ('triagem', 'norte'),
#  ('demais', 'candidatos'),
#  ('năło', 'sabem'),
#  ('opiniăło', 'polă'),
#  ('band', 'news'),
#  ('primeiro', 'debate'),
#  ('amigos', 'candidatos'),
#  ('primeiro', 'lugar'),
#  ('acidente', 'aăšreo'),
#  ('alguns', 'blogs')]

# %%
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures

# %%
procurar2 = TrigramCollocationFinder.from_words(texto)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('populaă', '§', 'ăło'),
#  ('#', 'casaarrumada', '#'),
#  ('§', 'ăło', 'de'),
#  ('#', 'horadavirada', '#'),
#  ('§', 'ăło', 'do'),
#  ('captaă', '§', 'ăło'),
#  ('concentraă', '§', 'ăło'),
#  ('corrupă', '§', 'ăło'),
#  ('educaă', '§', 'ăło'),
#  ('ligaă', '§', 'ăło'),
#  ('participaă', '§', 'ăło'),
#  ('reduă', '§', 'ăło'),
#  ('reeleiă', '§', 'ăło'),
#  ('intervenă', '§', 'ăło'),
#  ('#', 'rollemberg40', '#'),
#  ('§', 'ăło', 'serăą'),
#  ('apresentaă', '§', 'ăło'),
#  ('contribuiă', '§', 'ăło'),
#  ('convică', '§', 'ăło'),
#  ('coraă', '§', 'ăło'),
#  ('direă', '§', 'ăło'),
#  ('distribuiă', '§', 'ăło'),
#  ('eleiă', '§', 'ăło'),
#  ('filiaă', '§', 'ăło'),
#  ('fiscalizaă', '§', 'ăło'),
#  ('formaă', '§', 'ăło'),
#  ('iluminaă', '§', 'ăło'),
#  ('licitaă', '§', 'ăło'),
#  ('qualificaă', '§', 'ăło'),
#  ('§', 'ăło', 'atestada')]

# %%
filtra2 = lambda w: len(w) <3 or w in retira

# %%
procurar2.apply_word_filter(filtra2)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('distrito', 'federal', 'desde'),
#  ('distrito', 'federal', 'estăło'),
#  ('distrito', 'federal', 'vem'),
#  ('chico', 'leite', 'comerciantes'),
#  ('chico', 'leite', 'alăšm'),
#  ('lei', 'chico', 'leite'),
#  ('jornal', 'correio', 'braziliense'),
#  ('rodrigo', 'rollemberg', 'updated'),
#  ('rollemberg', 'updated', 'their'),
#  ('futuros', 'senadores', 'leila'),
#  ('instituto', 'opiniăło', 'polă'),
#  ('năło', 'sabem', 'avaliar'),
#  ('ďťżpost_message', 'vamos', 'juntos'),
#  ('răądio', 'band', 'news'),
#  ('caminhada40', 'vamos', 'juntos'),
#  ('passar', 'neste', 'săąbado'),
#  ('ainda', 'năło', 'sabem'),
#  ('updated', 'their', 'cover'),
#  ('updated', 'their', 'profile'),
#  ('\x9f\x91\x8d', 'neste', 'săąbado'),
#  ('neste', 'săąbado', 'tambăšm'),
#  ('mil', 'jovens', 'atendidos'),
#  ('mil', 'jovens', 'tanto'),
#  ('rollemberg40', 'neste', 'săąbado'),
#  ('maior', 'obra', 'viăąria'),
#  ('hăą', 'quatro', 'anos'),
#  ('ăşltimos', 'trăşs', 'anos'),
#  ('vamos', 'continuar', 'trabalhando'),
#  ('gestăło', 'conseguimos', 'colocar'),
#  ('păşblica', 'conseguimos', 'colocar')]
