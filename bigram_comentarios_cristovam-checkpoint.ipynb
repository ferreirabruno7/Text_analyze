# %%
import nltk
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
import re
import operator
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import words
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
# If you would like to work with the raw text you can use 'moby_raw'
with open('C:/Users/NB/Desktop/eleitorado/comentarios_cristovam.csv',  encoding='utf-8',) as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)

# %%
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\NB\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\webtext.zip.
# True

# %%
texto = [w.lower() for w in webtext.words('C:/Users/NB/Desktop/eleitorado/comentarios_cristovam.csv')]

# %%
texto
# Out:
# ['ďťżcomment_message',
#  '""',
#  '-',
#  'perfeita',
#  'suas',
#  'colocaă',
#  '§',
#  'ăľes',
#  'nobre',
#  'senador',
#  '.',
#  '"',
#  'â',
#  '\x80',
#  'ş',
#  'sen',
#  '.',
#  'contamos',
#  'com',
#  'seu',
#  'pronunciamento',
#  'ă',
#  'favor',
#  'do',
#  '#',
#  'votoimpressojăą',
#  'na',
#  'audiăşncia',
#  'păşblica',
#  'no',
#  'senado',
#  'federal',
#  'dia',
#  '06',
#  '/',
#  '03',
#  '/',
#  '2018',
#  'ă',
#  's',
#  '10',
#  ':',
#  '00',
#  'a',
#  'lei',
#  '13',
#  '.',
#  '165',
#  '/',
#  '2015',
#  'aprovada',
#  'pela',
#  '@',
#  'camaradeputados',
#  'e',
#  '@',
#  'senadofederal',
#  'seja',
#  'cumprida',
#  ',',
#  'a',
#  'urna',
#  'imprimirăą',
#  'cada',
#  'voto',
#  'e',
#  'serăą',
#  'dep',
#  '.',
#  'em',
#  'local',
#  'lacradoâ',
#  '\x80',
#  'ź',
#  '"',
#  '-',
#  'vc',
#  'que',
#  'decepă',
#  '§',
#  'ăło',
#  'foi',
#  'o',
#  'senhores',
#  '"""',
#  'com',
#  'ela',
#  'năło',
#  'dăą',
#  '...',
#  'um',
#  'grande',
#  'acordo',
#  'nacional',
#  'com',
#  'supremo',
#  ',',
#  'com',
#  'tudo',
#  '""',
#  '#',
#  'golpista',
#  'o',
#  'pior',
#  ',',
#  'vc',
#  'sabe',
#  'que',
#  'foi',
#  '#',
#  'golpe',
#  '"',
#  '"""',
#  'isso',
#  'tudo',
#  'ă',
#  '\x89',
#  'muito',
#  'engraă',
#  '§',
#  'a',
#  'eles',
#  'falaram',
#  'que',
#  'a',
#  'lei',
#  'foi',
#  'feita',
#  'para',
#  'todos',
#  'temos',
#  'văąrios',
#  'casos',
#  'de',
#  'condenados',
#  'na',
#  'segunda',
#  'estă',
#  '˘',
#  'ncia',
#  'que',
#  'năło',
#  'foram',
#  'presos',
#  'e',
#  'outros',
#  'ganharam',
#  'a',
#  'liberdade',
#  ',',
#  'entăło',
#  'senhor',
#  'senador',
#  'cristăłvăło',
#  'como',
#  'explicar',
#  'isso',
#  ',',
#  'mas',
#  'năłs',
#  'sabemos',
#  'que',
#  'o',
#  'lula',
#  'foi',
#  'condenado',
#  'em',
#  'cima',
#  'de',
#  'evidăşncia',
#  'ilusionismo',
#  ',',
#  'eu',
#  'ouvir',
#  'uma',
#  'reportagem',
#  'em',
#  'que',
#  'o',
#  'comentarista',
#  'dizia',
#  'que',
#  'se',
#  'năło',
#  'ouvesse',
#  'a',
#  'denuncia',
#  'o',
#  'lula',
#  'um',
#  'dia',
#  'antes',
#  'mudaria',
#  'para',
#  'o',
#  'apartamento',
#  ',',
#  'entăło',
#  'essa',
#  'palavra',
#  'tăą',
#  'no',
#  'futuro',
#  'ou',
#  'no',
#  'presente',
#  'na',
#  'verdade',
#  'com',
#  'todo',
#  'respeito',
#  'ele',
#  'ă',
#  '\x89',
#  'a',
#  'vidente',
#  'a',
#  'măłe',
#  'dina',
#  '."',
#  '"""',
#  'no',
#  'seu',
#  'artigo',
#  'elogia',
#  'o',
#  'golpe',
#  'militar',
#  'contra',
#  'as',
#  'reformas',
#  'socialistas',
#  'de',
#  'jango',
#  '""',
#  '-',
#  'em',
#  'que',
#  'artigo',
#  'vocăş',
#  'leu',
#  'isso',
#  '?',
#  'por',
#  'que',
#  'năło',
#  'foi',
#  'nesse',
#  '."',
#  '"""+/-',
#  'nada',
#  'com',
#  'nada',
#  '""',
#  'rs',
#  '""',
#  'olăą',
#  ',',
#  'obrigado',
#  'por',
#  'me',
#  'acompanhar',
#  'no',
#  'facebook',
#  'e',
#  'fazer',
#  'parte',
#  'da',
#  'minha',
#  'rede',
#  '.',
#  'esse',
#  'chatbot',
#  'irăą',
#  'te',
#  'acompanhar',
#  'nesta',
#  'conversa',
#  '.',
#  'escreva',
#  'quais',
#  'temas',
#  'vocăş',
#  'deseja',
#  'saber',
#  'mais',
#  'informaă',
#  '§',
#  'ăľes',
#  '""."',
#  '"""',
#  'a',
#  'eleiă',
#  '§',
#  'ăło',
#  'com',
#  'candidatos',
#  'cassados',
#  'pela',
#  'justiă',
#  '§',
#  'a',
#  'ăš',
#  'legal',
#  'e',
#  'democrăątica',
#  '""',
#  'se',
#  'săło',
#  'cassados',
#  'năło',
#  'eh',
#  'legal',
#  'e',
#  'nem',
#  'democratica',
#  ',',
#  'pois',
#  'ocupam',
#  'legendas',
#  'de',
#  'possă',
#  '\xad',
#  'veis',
#  'pessoas',
#  'ăšticas',
#  'e',
#  'honradas',
#  '."',
#  '"""',
#  'a',
#  'păągina',
#  'respondeu',
#  'em',
#  'particular',
#  '""...',
#  'talvez',
#  'decepcione',
#  'quem',
#  'tenta',
#  'entender',
#  'seu',
#  'posicionamento',
#  'polă',
#  '\xad',
#  'tico',
#  'diante',
#  'de',
#  'questăľes',
#  'expostas',
#  'aqui',
#  'pelos',
#  'usuăąrios',
#  '."',
#  '"""',
#  'agente',
#  '""?',
#  'do',
#  'fbi',
#  '?',
#  'da',
#  'polă',
#  '\xad',
#  'cia',
#  'federal',
#  '?',
#  'năło',
#  'sabe',
#  'nem',
#  'a',
#  'escrever',
#  'corretamente',
#  'um',
#  '""',
#  'a',
#  'gente',
#  '""',
#  'mas',
#  'sabe',
#  'que',
#  'foi',
#  '""',
#  'găłpi',
#  '""?',
#  'kkkk',
#  '"',
#  '"""',
#  'ain',
#  ',',
#  'vou',
#  'dizer',
#  'que',
#  'o',
#  'crsitovam',
#  'ăš',
#  'um',
#  'păšssimo',
#  'polă',
#  '\xad',
#  'tico',
#  'porque',
#  'ele',
#  'năło',
#  'tăą',
#  'mais',
#  'do',
#  'lado',
#  'que',
#  'eu',
#  'apoio',
#  '.""',
#  'hahahahahaha',
#  '...',
#  'vocăşs',
#  'săło',
#  'uma',
#  'grande',
#  'piada',
#  '.',
#  'melhor',
#  'governador',
#  'que',
#  'o',
#  'df',
#  'jăą',
#  'teve',
#  'que',
#  'vi',
#  'governando',
#  '."',
#  '"""',
#  'amanhăł',
#  'ă',
#  's',
#  'duas',
#  'horas',
#  'na',
#  'ceilă',
#  '˘',
#  'ndia',
#  'em',
#  'frente',
#  'ao',
#  'lote',
#  '14',
#  ',',
#  'e',
#  'ăš',
#  'pra',
#  'lăą',
#  'que',
#  'eu',
#  'vou',
#  '""',
#  '(',
#  'trecho',
#  'da',
#  'cană',
#  '§',
#  'ăło',
#  '""',
#  'faroeste',
#  'caboclo',
#  '""',
#  'da',
#  'legiăło',
#  'urbana',
#  ').',
#  'đ',
#  '\x9f\x98\x81"',
#  '"""',
#  'brasil',
#  '247',
#  '""....',
#  'tăą',
#  'serto',
#  '"',
#  '"""',
#  'cabe',
#  'anăąlise',
#  'dos',
#  'juristas',
#  ',',
#  'năło',
#  'sei',
#  'năło',
#  'estou',
#  'por',
#  'dentro',
#  'do',
#  'processo',
#  'de',
#  'collor',
#  '.""',
#  'os',
#  'juristas',
#  '(',
#  'stf',
#  ')',
#  'arquivaram',
#  'o',
#  'processo',
#  'contra',
#  'ele',
#  '."',
#  '"""',
#  'coerăşncia',
#  '""',
#  'golpista',
#  '"',
#  '"""',
#  'como',
#  'todos',
#  'os',
#  'outros',
#  '""...',
#  'sim',
#  '...',
#  'nada',
#  'mais',
#  'fascista',
#  'do',
#  'que',
#  'justificar',
#  'um',
#  'erro',
#  'com',
#  'outro',
#  '."',
#  '"""',
#  'deixaram',
#  'dăşvida',
#  'sobre',
#  'o',
#  'que',
#  'significa',
#  'tră',
#  '˘',
#  'nsito',
#  'em',
#  'julgado',
#  '""',
#  'dăşvida',
#  '?',
#  'o',
#  'constituinte',
#  'năło',
#  'poderia',
#  'ter',
#  'sido',
#  'mais',
#  'claro',
#  '!',
#  'tră',
#  '˘',
#  'nsito',
#  'em',
#  'julgado',
#  'ăš',
#  'um',
#  'conceito',
#  'inequă',
#  '\xad',
#  'voco',
#  ',',
#  'năło',
#  'hăą',
#  'jurista',
#  'que',
#  'discorde',
#  'sobre',
#  'isso',
#  '.',
#  'agora',
#  ',',
#  'se',
#  'apesar',
#  'da',
#  'clareza',
#  'e',
#  'precisăło',
#  'ă',
#  '\xad',
#  'mpar',
#  'com',
#  'que',
#  'o',
#  'constituinte',
#  'redigiu',
#  'esse',
#  'dispositivo',
#  ',',
#  'o',
#  'stf',
#  'quer',
#  'chamar',
#  'gato',
#  'de',
#  'lebre',
#  ',',
#  'dizendo',
#  'que',
#  'tră',
#  '˘',
#  'nsito',
#  'em',
#  'julgado',
#  'se',
#  'dăą',
#  'com',
#  'o',
#  'esgotamento',
#  'da',
#  '2a',
#  'instă',
#  '˘',
#  'ncia',
#  ',',
#  'năło',
#  'venha',
#  'culpar',
#  'o',
#  'constituinte',
#  '.',
#  'assuma',
#  'que',
#  'o',
#  'senhor',
#  'deseja',
#  'reescrever',
#  'a',
#  'cf',
#  '(',
#  'e',
#  'sem',
#  'respeito',
#  'ao',
#  'processo',
#  'de',
#  'emenda',
#  ').',
#  'triste',
#  'ver',
#  'o',
#  'que',
#  'o',
#  'senador',
#  'cristovam',
#  'se',
#  'tornou',
#  '.',
#  'tratando',
#  'do',
#  'tema',
#  'com',
#  'a',
#  'profundidade',
#  'de',
#  'um',
#  'tiozăło',
#  'no',
#  'grupo',
#  'da',
#  'famă',
#  '\xad',
#  'lia',
#  'no',
#  'whastapp',
#  '."',
#  '"""',
#  'democracia',
#  '""',
#  'kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk',
#  'vindo',
#  'de',
#  'vc',
#  '"',
#  '"""',
#  'e',
#  'tambăšm',
#  'independente',
#  'de',
#  'se',
#  'o',
#  'impeachment',
#  'de',
#  'collor',
#  'foi',
#  'ou',
#  'năło',
#  'foi',
#  'golpe',
#  ',',
#  'isso',
#  'năło',
#  'muda',
#  'a',
#  'caracterizaă',
#  '§',
#  'ăło',
#  'do',
#  'impeachment',
#  'de',
#  'dilma',
#  'como',
#  'golpe',
#  '"".',
#  'concordo',
#  '.',
#  'săł',
#  'queria',
#  'tu',
#  ',',
#  'ou',
#  'qualquer',
#  'outro',
#  'que',
#  'grita',
#  'golpe',
#  ',',
#  'conseguisse',
#  'dizer',
#  'algo',
#  'que',
#  'caracteriza',
#  'o',
#  'da',
#  'dilma',
#  'como',
#  'golpe',
#  'mas',
#  'năło',
#  'caracteriza',
#  'o',
#  'do',
#  'collor',
#  '."',
#  '"""',
#  'ă',
#  '\x89',
#  'vetado',
#  'quaquer',
#  'tipo',
#  'de',
#  'emenda',
#  'a',
#  'constituiă',
#  '\x87',
#  'ă',
#  '\x83',
#  'o',
#  'brasileira',
#  'em',
#  'tempos',
#  'de',
#  'intervenă',
#  '\x87',
#  'ă',
#  '\x83',
#  'o',
#  '!!""',
#  'nă',
#  '\x83',
#  'o',
#  'adianta',
#  'vc',
#  'ficar',
#  'citando',
#  'artigos',
#  'da',
#  'lei',
#  'para',
#  'um',
#  'senador',
#  'que',
#  'por',
#  'si',
#  'să',
#  '\x93',
#  'ă',
#  '\x89',
#  'um',
#  'estudioso',
#  'da',
#  'nossa',
#  'constituiă',
#  '\x87',
#  'ă',
#  '\x83',
#  'o',
#  '!!',
#  'nem',
#  'por',
#  'meio',
#  'de',
#  'plebicito',
#  '!!"',
#  '"""',
#  'eh',
#  'gorpii',
#  '""',
#  'esse',
#  'eh',
#  'o',
#  'ăşnico',
#  'mantra',
#  'que',
#  'os',
#  'alienados',
#  'petistas',
#  'sabem',
#  'repetir',
#  '!!!',
#  'vcs',
#  'săło',
#  'contra',
#  'o',
#  'fim',
#  'do',
#  'foro',
#  'privilegiado',
#  ',',
#  'precisa',
#  'falar',
#  'mais',
#  'alguma',
#  'coisa',
#  '???"',
#  '"""',
#  'entăło',
#  '...',
#  'estou',
#  'conversando',
#  'com',
#  'os',
#  'generais',
#  ',',
#  'comandantes',
#  'militares',
#  '.',
#  'estăą',
#  'tudo',
#  'tranquilo',
#  ',',
#  'os',
#  'caras',
#  'dizem',
#  'que',
#  'văło',
#  'garantir',
#  '.',
#  'estăło',
#  'monitorando',
#  'o',
#  'mst',
#  ',',
#  'năło',
#  'sei',
#  'o',
#  'quăş',
#  ',',
#  'para',
#  'năło',
#  'perturbar',
#  '.""',
#  '(',
#  'jucăą',
#  ',',
#  'romero',
#  ')"',
#  '"""',
#  'errou',
#  'em',
#  'năło',
#  'dissolver',
#  'o',
#  'congresso',
#  '""',
#  '(?!).',
#  'explique',
#  'isso',
#  'aă',
#  '\xad',
#  'direito',
#  '."',
#  '"""',
#  'grandes',
#  'mestres',
#  '""',
#  'fazem',
#  'a',
#  'cabeă',
#  '§',
#  'a',
#  'da',
#  'juventude',
#  ',',
#  'que',
#  'passa',
#  'a',
#  'acreditar',
#  'em',
#  'tudo',
#  'que',
#  'os',
#  '""',
#  'socialistas',
#  '""',
#  'ensinam',
#  '!"',
#  '"""',
#  'homenagem',
#  '""',
#  'de',
#  'quem',
#  'se',
#  'juntou',
#  'ă',
#  'quela',
#  'corja',
#  'para',
#  'derrubar',
#  'a',
#  'primeira',
#  'presidenta',
#  'do',
#  'brasil',
#  '.',
#  'uma',
#  'mulher',
#  'eleita',
#  'pelo',
#  'povo',
#  '.',
#  'cadăş',
#  'a',
#  'coerăşncia',
#  ',',
#  'senador',
#  '?"',
#  '"""',
#  'independente',
#  'do',
#  'măšrito',
#  ',',
#  'essa',
#  'discussăło',
#  'de',
#  'golpe',
#  'năło',
#  'havia',
#  'no',
#  'processo',
#  'de',
#  'impeachment',
#  'de',
#  'collor',
#  '.""',
#  'essa',
#  'foi',
#  'a',
#  'pior',
#  'resposta',
#  'que',
#  'eu',
#  'poderia',
#  'imaginar',
#  ',',
#  'wilson',
#  'cabăşs',
#  '!',
#  'o',
#  'fato',
#  'de',
#  'ninguăšm',
#  'ter',
#  'sido',
#  'pago',
#  'pelo',
#  'collor',
#  'para',
#  'gritar',
#  '""',
#  'ăš',
#  'golpe',
#  '""',
#  'na',
#  'rua',
#  ',',
#  'como',
#  'aconteceu',
#  'com',
#  'a',
#  'dilma',
#  ',',
#  'ăš',
#  'o',
#  'argumento',
#  'para',
#  'dizer',
#  ...]

# %%
procurar = BigramCollocationFinder.from_words(moby_tokens)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('!', '!'),
#  ("''", '``'),
#  ('.', "''"),
#  ('Cristovam', 'Buarque'),
#  ('?', '?'),
#  ('o', 'senhor'),
#  (',', 'mas'),
#  ("''", "''"),
#  ('ensino', 'médio'),
#  ('https', ':'),
#  ('!', "''"),
#  ('O', 'senhor'),
#  ('meu', 'voto'),
#  ('.', 'O'),
#  ('da', 'educação'),
#  ('.', '``'),
#  ('``', "''"),
#  ('com', 'o'),
#  ('.', 'Não'),
#  ('.', ','),
#  ('é', 'um'),
#  ('a', 'favor'),
#  ('!', '``'),
#  ('.', 'Mas'),
#  (',', '.'),
#  ('foro', 'privilegiado'),
#  ('que', 'o'),
#  ('o', 'povo'),
#  ('Senador', ','),
#  (',', ',')]

# %%
from nltk.corpus import stopwords

# %%
retira = set(stopwords.words('portuguese'))

# %%
retira
# Out:
# {'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'não',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'à',
#  'às',
#  'éramos'}

# %%
filtra = lambda w: len(w) <3 or w in retira

# %%
procurar.apply_word_filter(filtra)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('Cristovam', 'Buarque'),
#  ('ensino', 'médio'),
#  ('foro', 'privilegiado'),
#  ('ensino', 'superior'),
#  ('Parabéns', 'Senador'),
#  ('Cristóvão', 'Buarque'),
#  ('escola', 'pública'),
#  ('deve', 'ser'),
#  ('segunda', 'instância'),
#  ('Senador', 'Cristovam'),
#  ('ter', 'sido'),
#  ('Parabéns', 'senador'),
#  ('cada', 'vez'),
#  ('ensino', 'fundamental'),
#  ('alguma', 'coisa'),
#  ('educação', 'básica'),
#  ('universidades', 'públicas'),
#  ('Ensino', 'Médio'),
#  ('vossa', 'excelência'),
#  ('bom', 'ensino'),
#  ('pode', 'ser'),
#  ('auxílio', 'moradia'),
#  ('ficar', 'calado'),
#  ('São', 'Paulo'),
#  ('povo', 'brasileiro'),
#  ('governo', 'Lula'),
#  ('liberdade', 'acadêmica'),
#  ('carro', 'oficial'),
#  ('ensino', 'básico'),
#  ('reforma', 'trabalhista')]

# %%
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures

# %%
procurar2 = TrigramCollocationFinder.from_words(moby_tokens)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('!', '!', '!'),
#  ('.', "''", '``'),
#  ('!', '!', '``'),
#  ('!', '!', "''"),
#  ("''", "''", '``'),
#  ('!', '!', '.'),
#  ('.', '!', '!'),
#  ('Parabéns', '!', '!'),
#  ('!', '!', 'de'),
#  ('senador', '!', '!'),
#  ('Senador', '!', '!'),
#  ("''", '!', '!'),
#  ('!', '!', 'e'),
#  ('!', '!', 'o'),
#  ('!', '!', 'O'),
#  ('!', '!', 'Parabéns'),
#  ('!', '!', 'Não'),
#  ('!', '!', 'não'),
#  ('!', '!', 'Que'),
#  ('!', '!', 'A'),
#  ('!', '!', 'com'),
#  ('!', '!', 'E'),
#  ('Perfeito', '!', '!'),
#  ('!', '!', 'Mas'),
#  ('!', '!', '?'),
#  ('!', '!', 'um'),
#  ('para', '!', '!'),
#  ('em', '!', '!'),
#  ('...', '!', '!'),
#  ('!', '!', 'Um')]

# %%
filtra2 = lambda w: len(w) <3 or w in retira

# %%
procurar2.apply_word_filter(filtra2)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('Senador', 'Cristovam', 'Buarque'),
#  ('senador', 'Cristovam', 'Buarque'),
#  ('Professor', 'Cristovam', 'Buarque'),
#  ('sen.', 'Cristovam', 'Buarque'),
#  ('Parabéns', 'Cristovam', 'Buarque'),
#  ('Caro', 'Cristovam', 'Buarque'),
#  ('Sr.', 'Cristovam', 'Buarque'),
#  ('Sen.', 'Cristovam', 'Buarque'),
#  ('SENADOR', 'Cristovam', 'Buarque'),
#  ('Cristovam', 'Buarque', 'Dialogar'),
#  ('Cristovam', 'Buarque', 'Entra'),
#  ('Cristovam', 'Buarque', 'morace'),
#  ('Cristovam', 'Buarque', 'sucks'),
#  ('Definitivamente', 'Cristovam', 'Buarque'),
#  ('Hahahahahahahahaha', 'Cristovam', 'Buarque'),
#  ('LIBERTINAGEM', 'Cristovam', 'Buarque'),
#  ('condena', 'Cristovam', 'Buarque'),
#  ('loko', 'Cristovam', 'Buarque'),
#  ('sucks', 'Cristovam', 'Buarque'),
#  ('poupe', 'Cristovam', 'Buarque'),
#  ('chama', 'Cristovam', 'Buarque'),
#  ('Prezado', 'Cristovam', 'Buarque'),
#  ('Cristovam', 'Buarque', 'fala'),
#  ('Fora', 'Cristovam', 'Buarque'),
#  ('Cristovam', 'Buarque', 'compactuou'),
#  ('Cristovam', 'Buarque', 'destrói'),
#  ('Cúmplice', 'Cristovam', 'Buarque'),
#  ('Salve', 'Cristovam', 'Buarque'),
#  ('utm_source=share_petition', 'Cristovam', 'Buarque'),
#  ('Cristovão', 'Cristovam', 'Buarque')]

# %%
procurar2.apply_freq_filter(3)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('Senador', 'Cristovam', 'Buarque'),
#  ('senador', 'Cristovam', 'Buarque'),
#  ('Professor', 'Cristovam', 'Buarque'),
#  ('sen.', 'Cristovam', 'Buarque'),
#  ('Parabéns', 'Cristovam', 'Buarque'),
#  ('SENADOR', 'Cristovam', 'Buarque'),
#  ('Cristovam', 'Buarque', '...'),
#  ('bom', 'ensino', 'médio'),
#  ('ensino', 'médio', 'ruim'),
#  ('péssimo', 'ensino', 'médio'),
#  ('ensino', 'médio', 'graças'),
#  ('ótimo', 'ensino', 'médio'),
#  ('Parabéns', 'Senador', 'Cristovam'),
#  ('Senador', 'Cristóvão', 'Buarque'),
#  ('senador', 'Cristóvão', 'Buarque'),
#  ('Parabéns', 'senador', 'Cristovam'),
#  ('Parabéns', 'Senador', '...'),
#  ('ter', 'sido', 'demitido'),
#  ('poderia', 'ter', 'sido'),
#  ('...', '...', '...'),
#  ('pode', 'ser', 'chamado'),
#  ('fazer', 'alguma', 'coisa'),
#  ('pode', 'ser', 'considerado'),
#  ('uso', 'carro', 'oficial'),
#  ('melhor', 'ficar', 'calado'),
#  ('ficar', 'calado', 'senador'),
#  ('recebo', 'auxilio', 'moradia'),
#  ('maior', 'decepção', 'política'),
#  ('preventiva-', 'bolsa', 'escola'),
#  ('dia', 'ter', 'votado')]
